# %%
import pandas as pd
from glob import glob
from PIL import Image
import matplotlib.pyplot as plt

# %%
def paths_to_df(lista):
    final=pd.DataFrame(columns=['id', 'text','sentiment',  'path'])
    for fol in lista:
        dat=pd.read_csv(fol)
        dat['path']=dat[['id','hashtag']].apply(lambda x : f'..\data\\{x[1]}\images\\{x[0]}.png', axis=1)
        dat=dat.drop(columns=['date', 'url'])
        final=final.append(dat, ignore_index=True)
    final=final[final.sentiment != 'discard']
    return final
    

def df_generator(path, split=False):
    dati=glob(f'{path}\*\*labeled.csv')
    if split==False:
        result=paths_to_df(dati)
        return (result)
    else:
        train=paths_to_df(dati[split:])
        test=paths_to_df(dati[:split])
        return(train, test)
    
def balancer(df):
    g = df.groupby('sentiment')
    res=pd.DataFrame(g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True)))
    res=res.droplevel(level=0)
    res=res.reset_index().drop(columns=['index'])
    
    return res

# %%
train_, test_=df_generator('..\data', split=3)

# %%
train_
# Out:
#                         id                                               text  \
# 0      1321403480133799937  “E ci sei\nadesso tu”\n\nFacciamo tanti auguri...
# 1      1321375576368861185  Come la tv sta trattando l'ecologia, proprio i...
# 3      1321194101073711104  Durante la clip su Ornella si è sentita la sua...
# 4      1321169330047012866  “Siamo sicuri che il problemi siano i bar e i ...
# 6      1321119330445205504  RT fabfazio 📺 ⁦@chetempochefa⁩ torna domenica ...
# ...                    ...                                                ...
# 10589  1088779289842073600  Meraviglioso #LinoGuanciale 😍🔝👍🏻 #attore #teat...
# 10590  1088427884807626752  «Enrico, evolve, non diventa un superuomo però...
# 10591  1087254127988695042  Per iniziare bene la giornata😍 Buongiorno my l...
# 10592  1086818197519646721  Finale degno di nota e ti prego Rai non ammazz...
# 10597  1083735802021064704  «Il fatto di vederlo in difficoltà, e in quest...
#
#       sentiment                                               path  \
# 0      positive        ..\data\CTCF\images\1321403480133799937.png
# 1       neutral        ..\data\CTCF\images\1321375576368861185.png
# 3       neutral        ..\data\CTCF\images\1321194101073711104.png
# 4       neutral        ..\data\CTCF\images\1321169330047012866.png
# 6       neutral        ..\data\CTCF\images\1321119330445205504.png
# ...         ...                                                ...
# 10589  positive  ..\data\nondirloalmiocapo2\images\108877928984...
# 10590  positive  ..\data\nondirloalmiocapo2\images\108842788480...
# 10591  positive  ..\data\nondirloalmiocapo2\images\108725412798...
# 10592  positive  ..\data\nondirloalmiocapo2\images\108681819751...
# 10597  positive  ..\data\nondirloalmiocapo2\images\108373580202...
#
#                   hashtag
# 0                    CTCF
# 1                    CTCF
# 3                    CTCF
# 4                    CTCF
# 6                    CTCF
# ...                   ...
# 10589  nondirloalmiocapo2
# 10590  nondirloalmiocapo2
# 10591  nondirloalmiocapo2
# 10592  nondirloalmiocapo2
# 10597  nondirloalmiocapo2
#
# [7854 rows x 5 columns]

# %%
test_
# Out:
#                        id                                               text  \
# 0     1321341245185286145  concorrenti di amici19 che per guadagnare qual...
# 1     1319754525708832769  ACCADDE STASERA: #23ottobre 2019, 1 anno fa Pa...
# 2     1319685252378464256  Recensione #RidoMale #Tish \n1°brano in italia...
# 3     1319605426367942662  Se dopo #XFactor, con Emma, se lo fa scappare ...
# 4     1319605052508602368  Domani alle 21:30 torna l'appuntamento settima...
# ...                   ...                                                ...
# 3539  1101221393172185088  Suor Angela pronta ad indagare sul dottore 😂😂 ...
# 3540  1101219592012292098  Amo questa coppia ❤️🤩 @CheDioCiAiuti_5 https:/...
# 3543  1101217979377758208  «Volete sapere come si scoraggia un uomo? Moll...
# 3544  1101217486152830976  Giovedì sera = divano e #CheDioCiAiuti5 @CheDi...
# 3545  1101216719920488448  ⚡MESSAGGIO IMPORTANTE⚡\na tutti gli amici del ...
#
#      sentiment                                               path  \
# 0     negative     ..\data\amici19\images\1321341245185286145.png
# 1      neutral     ..\data\amici19\images\1319754525708832769.png
# 2      neutral     ..\data\amici19\images\1319685252378464256.png
# 3     positive     ..\data\amici19\images\1319605426367942662.png
# 4      neutral     ..\data\amici19\images\1319605052508602368.png
# ...        ...                                                ...
# 3539  positive  ..\data\chediociaiuti\images\11012213931721850...
# 3540  positive  ..\data\chediociaiuti\images\11012195920122920...
# 3543  positive  ..\data\chediociaiuti\images\11012179793777582...
# 3544  positive  ..\data\chediociaiuti\images\11012174861528309...
# 3545   neutral  ..\data\chediociaiuti\images\11012167199204884...
#
#             hashtag
# 0           amici19
# 1           amici19
# 2           amici19
# 3           amici19
# 4           amici19
# ...             ...
# 3539  chediociaiuti
# 3540  chediociaiuti
# 3543  chediociaiuti
# 3544  chediociaiuti
# 3545  chediociaiuti
#
# [3249 rows x 5 columns]

# %%
fig, ax = plt.subplots()
train_['sentiment'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %%
train_balanced=balancer(train_)
train_balanced['sentiment'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
len(train_balanced)
# Out:
# 4746

# %%
test_balanced=balancer(test_)
len(test_balanced)
# Out:
# 1281

# %%
train_balanced.to_csv('train_final.csv')
test_balanced.to_csv('test_final.csv')

# %%
train_balanced['path'][0]
# Out:
# '..\\data\\nondirloalmiocapo2\\images\\1297630430989090817.png'

# %%
from PIL import Image
import pytesseract
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import time
import cv2
from tqdm import tqdm 

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
def preprocess_final(im):
    im= cv2.bilateralFilter(im,5, 55,60)
    im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    _, im = cv2.threshold(im, 240, 255, 1)
    return im

# %%
custom_config = r"--oem 3 --psm 11 -c tessedit_char_whitelist='ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz '"

# %%
res=[]
for p in tqdm(list(test_balanced['path'])):
    im=np.array(Image.open(p))
    try:
        im=preprocess_final(im)
        text = pytesseract.image_to_string(im, lang='ita', config=custom_config)
        res.append((text.replace('\n', '').replace('\x0c', '')[0:50]))
    except:
        res.append('')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1281/1281 [04:37<00:00,  4.62it/s]

# %%
res
# Out:
# ['',
#  'sANNAMOIBENE',
#  'GiadahsospesaGiadahsospesaplteNahhh non la prima g',
#  '',
#  '',
#  'NO MARIA IO ESCO',
#  '',
#  '',
#  '',
#  '',
#  'i ES',
#  ' SorrisicomseeAulti Mae LISSONE TIAil Convento deg',
#  'Tanto lo sappiamoche andato tutto a puttane no',
#  'neG LINO GUANCIALE ITALIA',
#  'A RIDICOLIIIII',
#  'BASTA',
#  'TI DEVI VERGOGNARE',
#  '',
#  'MA COSA STAI DICENDO',
#  '',
#  '',
#  '',
#  '',
#  'BASTAI',
#  'TRASH ITALIGHOPIENA',
#  '',
#  'SE STAI ROSICANDO',
#  'silosSTRUNZ',
#  '',
#  'TRASH ITALIANO',
#  'I',
#  '',
#  '',
#  'A RIDICOLIIIII',
#  'fr',
#  'TRASH ITALIANO',
#  '',
#  '',
#  'S',
#  '',
#  'emi l ol al LLTS LLtalisajade Buona Pasquahapppyea',
#  'Sono scioccato',
#  'Sai quanti cerealisottomarca ti devimangiare ancor',
#  'NON SE NE PU',
#  '',
#  'Ci lower your voice',
#  'VIPERISSIMAdla QUALCOSAQUALCOSA DI ATROCE',
#  '',
#  'Che merda Dio Santo che merda',
#  'TRASH ITALIANOE iI FISSI QUI FUORI OGGI',
#  'ARSAFfaIliVOTANO GIURIAPROFESSORI VAR',
#  'TRASH ITILAMIdI',
#  'A',
#  'Ninln',
#  '',
#  'BASTA',
#  '',
#  'Hallelujah',
#  'zn ro a',
#  'LA',
#  '',
#  '',
#  'iVIPERISSIMAN',
#  'LandropausaP',
#  '',
#  'TRASH ITALIANOci Fcone CAFONATA RAGAZZI',
#  '',
#  'mrFANTASTICO',
#  'A adiParrucchieri e centri estetici chiusi epoi De',
#  ' dBAH',
#  'Disapprovo',
#  '',
#  'UT',
#  'BASTA ME SO STUFATA',
#  'Non voglio dire pafolaccel ha',
#  '',
#  'sersetimaPlay',
#  '',
#  'TRASH ITALIGNOFORSE IO PER MI UCCIDO',
#  'Nevv',
#  '',
#  'VIPERISSISIAseUN SOTTONE',
#  '',
#  '',
#  '',
#  'TRASH ITALIAKOsuPER ME BASTA COS',
#  '',
#  'a NONHO CAPITO UN CAO',
#  '',
#  '',
#  'TRRIECALIANEAnDGGI ESCO DEFINITIVAMENTE',
#  '',
#  '',
#  'aanicoxcutelSGpifo leesGgLISeguiMessaggioAncora ne',
#  'VIPERISSIMAANDIAMO VELOCI',
#  '',
#  'BUON',
#  'Se vabbe',
#  '',
#  '',
#  'GsNDO STAI',
#  'nLIxAadi',
#  'VIPERIS SEMIO QUELLI COME TE LI SGAMO',
#  '',
#  '',
#  '',
#  '',
#  'AIasivotaTAG RIA',
#  '',
#  '',
#  'ZRete SeFitto an CETE Rete e letotte tte tutte Hi ',
#  '',
#  'VERAMENTE NON HO PAROLE',
#  'MA ROBA DA PAZZII',
#  'VIPERISSIMAIO SONO SOTTO SHOCK',
#  '',
#  'NVOURE FIRED',
#  'CLqulieg',
#  '',
#  '',
#  'Bz HA QUESTO UN',
#  'duTRASH ITALIANOCHISSA COME MAI',
#  '',
#  '',
#  'dhxdAcENio',
#  '',
#  '',
#  '',
#  'CHE DIO GI AIUTI',
#  'nun simm scem clarouv',
#  'n si PI',
#  'IL SCIACQUI LA BOCCA Pol PARLI',
#  'VIPERISSIMANO MA COS UNA MERDA',
#  '',
#  'TsVIPREGO IN GINOCCHIO',
#  'VIPERISSIAIA',
#  'PIENA',
#  '',
#  'ErecasEbtPER QUANTO MI RIGUARDA',
#  '',
#  'licSLe EN ELpostfollowerseguitiUtente non trovatoE',
#  'TRASH ITALIONOGI NON CELA FACCIO PI',
#  'ALL DF US NOV',
#  'dn ino',
#  'BASTARDI VERI',
#  'iMI VIENE Be pitaRE',
#  'TRASH ITALIONOGHE GAZZO FATE',
#  'disappointedeebut not surprised',
#  'COSEDAPAARAZZI',
#  '',
#  'TRASH ITALIONOe NONCI SIAMO PROPRIO',
#  '',
#  '',
#  '',
#  '',
#  'GiadahsospesaGiadahsospesaplitcestlaviemacher lui ',
#  'TRASH ITALIANOSEFFALSAI',
#  'NE DAI SUI',
#  'SEI FORTEad',
#  'TRASH ITALIANOUN CALCIO IN CULO COL DECOLLO',
#  '',
#  'n El Passatolesame da giornalistacome Suarez quell',
#  '',
#  'TU SEI PAZZA TOTALE FIGLIA MIA',
#  '',
#  'Sf',
#  'QUA MANCANO PROPRIO LE BASI',
#  '',
#  'A',
#  'CommentiNdrakygISGmequentatoper dire che come pers',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'NE DAI SUI',
#  'TRASH ilALIANOMOLTO SDIBELELEIBA',
#  'EHALATimgPlay',
#  'oguo ITEAh ansaitELasicniANSA Viaggi ArtCostantino',
#  'caiMa perche',
#  'TRASH ITAL',
#  'taFA SCHIFO',
#  '',
#  'A',
#  'FILI NOVEMBRE IN PERSONA',
#  'onde',
#  'BUON',
#  'MA CHE STAI A DII',
#  'A CAZZO DI CANE',
#  'MAI PIU',
#  'OMR SETimgPlay',
#  'VIPERISSIMADOPO QUESTA ADDIO',
#  'i',
#  'NO MATUIIDAPPOSTO',
#  'AMEN',
#  '',
#  '',
#  'jacopo e ce fatt doij pall SI GAIA  LPIU GNOCCA NO',
#  'CTOEQuLD',
#  'ti',
#  'vdgiulymolla mia ideadi FELICITAOIr SI UMTS as agi',
#  'TORNA A CASA E SI DISINTOSSICA',
#  '',
#  'Vorrei piangere per rido',
#  'VIPERISSIMAaMA DOVE',
#  '',
#  'francescachillemiCRAmextadsMhUsanipridInvia messag',
#  'bOCAINI',
#  'VIPERISSIMASCUSAMI CHE COSA STAI DICENDO',
#  '',
#  '',
#  '',
#  ' dBAH',
#  'Id Nannini pais e lol ivato merz iataLelniEa Neno ',
#  '',
#  '',
#  'MA CHE STA TRISTEZZA',
#  'A',
#  '',
#  'sS',
#  '',
#  '',
#  '',
#  'CHIEDO',
#  '',
#  'svtoinisn pr arva Eper',
#  'ramanecivaiESCLUSIVAsuniprin',
#  'eleonoraabbagnatoofticialPromofestivalnerviNaviuit',
#  '',
#  'NA GAFONATA',
#  '',
#  'GiadahsospesaiGiadahsospesaplflui forse neconsapev',
#  'E ripeto che non sieteobbligati a fare il terzogra',
#  'wJTAa',
#  'MI SONO SPAVENTATA',
#  'Fai schifo',
#  '',
#  '',
#  '',
#  'CI SEI',
#  '',
#  'AEd',
#  'TRASH ITALIANOPIENA',
#  'NotOA VvNOSSEI LOImonicaceleste Su studia l chedio',
#  'FUORI',
#  '',
#  '',
#  'VIPERISSIMA',
#  '',
#  'ai NO FAMMI FI',
#  '',
#  'annapettinellicon rossbresciaIn diretta GXii',
#  'NetuVoi non ci state con la testa ragazzi',
#  'CHE PALLE',
#  'maini',
#  'do',
#  'Seeee vabbe',
#  'UN POCAFONCELLO',
#  'LE GIF DI TINAGs',
#  '',
#  'NON HA CAPITO PROPRIO NIENTE',
#  '',
#  '',
#  'jivftMR TITTI APFISTURS',
#  'MADRE DI DIO',
#  'FStuNTZLdiiMAZZOdiCRPITTIcif ditiCIUPIIURIaa',
#  'id TendiStai in questo pianeta o no',
#  '',
#  'IdFa',
#  '',
#  'caj',
#  'SI GI CREDIAMO TUTTI',
#  'i X',
#  'Domani si registra soloil trono overLa scelta di G',
#  '',
#  '',
#  '',
#  '',
#  'annapettinelliIN DIRETTA GI',
#  'DONOTWANT',
#  '',
#  'Ma voi siete PAZZI',
#  'pes ss maFOLLIA',
#  '',
#  'sANNAMOIBENE',
#  'jivftMR TITTI APFISTURS',
#  'SILGNE Sab Ibi',
#  '',
#  'Parrucchieri e centri estetici chiusi eHIespoiDevo',
#  'sesSelvaggia Lucarelli aprGLospedale in fiera non ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'i',
#  '',
#  'uda',
#  'SONOINCL',
#  '',
#  '',
#  '',
#  'pingdnirvesivaLium',
#  '',
#  'MAI UNA GIOIA',
#  '',
#  '',
#  'MADRE DI DIO',
#  'EMINEM dalle tipe cheidicono di essere state conta',
#  '',
#  'VIPERISSIMA',
#  'IL cervello mio sta andando',
#  'omarzrobiesNEi finuiXrKy YYLisulilililpalesula io ',
#  'IL SCIACQUI LA BOCCA Pol PARLI',
#  'VIPERISSIMABUSINESS',
#  '',
#  'MA IMPAZZITO',
#  'n',
#  'TRASH ITALIANOMA VAFFANCULO VA',
#  '',
#  '',
#  'skioffitanmeniezidolutnucatitadiFiilxhwrpoinelLLJM',
#  'TRASH ITALIAHOPORELLO',
#  '',
#  'IO UN CELA FO',
#  'METFLIX',
#  'tiaaNOn alzi TRAsaI',
#  '',
#  '',
#  'llGiadahsospesaLLGiadahsospesaplReplying to michva',
#  'i',
#  'cambiamentoradicale ela Riccihaspiegato comeaffron',
#  'ffDA',
#  'RETI',
#  'do not want',
#  'ir',
#  '',
#  '',
#  '',
#  'NO BUONOCILLATimSPlay',
#  'TRASH ITALIONOCOSA VUOI DA MEP',
#  '',
#  'mi LITIcoVA',
#  'ulii',
#  '',
#  'aboutril',
#  'niloTRESH ITALICHOSCHIFO',
#  'EHALATimgPlay',
#  '',
#  'omarzrobiesNEi finuiXrKy YYLisulilililpalesula io ',
#  'n eTuxiBASTA',
#  'aYx',
#  'MA DIO CE NE LIBERI',
#  '',
#  'NO MARIA IO ESCO',
#  'AND YET HERE YOU ARE',
#  'chediocianiti officialaidaVSdrailofficialCENInvia ',
#  '',
#  '',
#  '',
#  'fIM A BARBIE GIRL',
#  '',
#  '',
#  'omarzroblesLitinifiniAiDI ra i vILildIpaleomeymate',
#  'LihiFCETimo rsUi fiIaUUx aoT mmieneadtnXXAAerpreET',
#  'CENTODICIOTTOOO',
#  '',
#  '',
#  '',
#  'IVANFABIOCAROLYNSELVAGGIAGUILLERMOZAZZARONICANINOS',
#  '',
#  'rase mnVERGOGNA VERGOGNA VERGOGNA',
#  'iaviufficialeBi AE AldezioAhadInvia messaggio',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Bee  iiiint ai RAEGigi Sirdischi di platino booo a',
#  'AMEN',
#  'NON HO PAROLE',
#  'SIAMO',
#  'dI KABuon g PRiuWi',
#  'fren aNEdi',
#  'MA DAI MARIA E BASTA',
#  '',
#  'VIPERISSIMAdaIO NON LO ACCETTO',
#  'kidenLa biondina di sind',
#  'e',
#  '',
#  'TRASH ITALIONOMA GHE STA CAFONATAP',
#  '',
#  '',
#  'duPoniSiamo rimasti senza soldil',
#  'NON POSSO',
#  '',
#  'VIPERISSIMASONO SCONVOLTO ECCOIN POCHE PAROLE',
#  'VIPERISSIMAVAI A CAPIRE',
#  '',
#  'EST eta uEt E',
#  'VIFZRISSIMA',
#  '',
#  'GiadahsospesaGiadahsospesaplQualcuno conosce a sta',
#  'j x',
#  '',
#  'VIPERISSIMAINCOMMENTABILE',
#  'CheDioCiAiutiSGIOVEDZb',
#  '',
#  '',
#  '',
#  'aniFalDIti vat RI CHID',
#  '',
#  'MA COSE UNA CLINICAPSICHIATRICA QUESTAP',
#  'rationrBXFOQUESTO ME LO RICORDOCOME UNA PIPPA',
#  '',
#  'NON NE POTEVO PIU',
#  'CHE DIO GI AIUTI',
#  'TRASH UMUSHOAiSS wohiTI QUERELOI',
#  '',
#  'i',
#  'FiUs',
#  '',
#  'f',
#  'NO per carita',
#  'saMILLY CARLUCCI SI SUPERA ILMIGLIOR DATO DI BALLA',
#  'PROGRAMMI IN TV STASERAGIOVEDI LUGLIOwwwSPETTACOLO',
#  'haii',
#  'vSn',
#  'nHrRxnLLTIM nIcAn',
#  'Volpe REALVolpeRealSei bloccato in ascensore con l',
#  'TALIOAOGGI orelll',
#  '',
#  'AllS',
#  '',
#  'niclonSCRTOPSI CONTENUTI TV PI SOCIAL IN ITALIAdDb',
#  '',
#  'brRai BIlsTutti i soldi delNC UnitEuforiamondoanti',
#  '',
#  'sreLaskoz',
#  'lLiiis alalinezizia',
#  '',
#  'SAxAprA fetimi sono sentita sposataOMESIEPIRATA AA',
#  '',
#  'botiiiaGAIA GOZZI MIRKO CASADETCUPENN NSA SEGioved',
#  '',
#  'yiMiavicd',
#  'CheDioCiAluthx CDCAS',
#  'SiAflLadsiidiYodottrdl',
#  'giulycookieUT A UltSalo se non lhal gi fattoTNTott',
#  'Alberto Urso con la suapartecipazione al Festival ',
#  'w',
#  'DI',
#  'Amici GaiaShagauaAmici di Maria De FiliZ mesi fa v',
#  'o DJavier zlm just boredRomeFrom Cubailm a Dancer ',
#  'E',
#  '',
#  'Sa',
#  '',
#  '',
#  'LalmimilaiQPAanwaweErtlaisa VirATER ui kiilGioved ',
#  'hei',
#  'MARTINAsabato maggio oreospite mr',
#  'iL',
#  '',
#  'CONVENT MYSTERIESSOESlaveJTTboa',
#  'BE',
#  'IzUilvGiDrCibo cid',
#  'BLaetre relen',
#  'dA',
#  'ciimgPlay',
#  '',
#  'yiMiavicd',
#  '',
#  'giulymolcorprdavrei condiviso con voi una cosaper ',
#  'dianadelbufalonWIPfrdiAtaLettura copione',
#  '',
#  'n',
#  '',
#  '',
#  'dianadelbutaloHSTUDIANDO',
#  'LA',
#  'Aueeer',
#  'hei',
#  '',
#  'SAdlztriniVELkadUSRESInSPAUOvrPIEIdARAIgovvaMOCCHb',
#  'DOMANI SERAIN PRICidefe',
#  'javiufficialeIN DIRETTA I',
#  'ottonellojYou the Tank Engine da soelculdInvia mes',
#  'UL RT IERRATA ITTECOLOTEOLIE CIAEICostantinoGuenda',
#  '',
#  'amiciu fficialeOOArioI CASTINGSONO APERTI',
#  'uL',
#  'Nx',
#  '',
#  '',
#  'IU',
#  'o Y',
#  'gingerdiDenexini',
#  'I',
#  '',
#  '',
#  'HiINIrie',
#  '',
#  'I Luglio',
#  'mi Za WoE ANCHE A CHI GI VUOLE MALE',
#  'x',
#  '',
#  'Gi PlayXIORESTOACASAHmessaggio degli a',
#  'a',
#  'e',
#  'eriuasenaxw',
#  '',
#  '',
#  'Alberto UrsoO maggioCanale creatoFoto del canale c',
#  'GAYVVENY',
#  'CONVENT MYSTERIESSOSEZOlavSegaTToudic',
#  '',
#  'categoriaCANTO',
#  '',
#  '',
#  '',
#  'JAVIERospite Asabato maggio ore dO',
#  'UN BAGIONE',
#  'IaeGIULIA MOLINOIe',
#  'CONVENT MYSTERIESSOElavTHTa',
#  'fc Ap',
#  'SERYOJACOPO',
#  '',
#  '',
#  'Eh',
#  '',
#  'AanzoneSodaHerfiativiTireneDies',
#  '',
#  'i Z',
#  'Chi Divt AmnbiCOME ERAVAMOI',
#  'UdeadPaCIN',
#  'VIPERISSIBIA',
#  '',
#  '',
#  '',
#  'TRASH ITALIANO',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'toBia',
#  '',
#  'patta felitgiugnolA VAIL RE TTSECRASAProgrammaSEIC',
#  'SPECIALIINSIEME PERL AL',
#  'd',
#  'complexionsballetdanehsane tirOInvia un messaggio',
#  'NON SI PUO DIRE',
#  'NON LO DEVO DIRE',
#  'neunN',
#  'a',
#  'TTpatdeaDiANGEL CAKEDLLMERINGHE ROSAI razo c',
#  '',
#  'diopgietoeneURVAdunNIfe',
#  'teeeeim',
#  'Video in diretta di robymSiniziatomimigAsquadVolo ',
#  'Chi Diel AhiCOME ERAVAMOI',
#  'patta felitXbgiugnoUT RAVA TR AATSEProgrammaCRASAS',
#  'va Lo',
#  '',
#  '',
#  '',
#  'Jbr d',
#  'CauabiATTENTIONSeatCheneyStayAtHome',
#  'TRASH ITRLIGNO',
#  'iu',
#  'giulymol piu forte Un video amatoriale con le suei',
#  'JACOPOSETTeiNWedCOME IL SOLE',
#  'SOCIALBLOGIv',
#  'giulymolsta scriventdo',
#  'pf',
#  'uielea',
#  'ProssimamenteDMSAHND',
#  'nl',
#  'IfIgiulycookieFai una domanda adelodie aIradiocrcF',
#  '',
#  '',
#  'rrgiulycookie iil Martina Beltrami Luci AcceseXxXO',
#  'TRASH ITALIANOIL MONDO DELLA DANZA SA',
#  'giulymoldbniavrei condiviso con voi una cosaper me',
#  'citt dii ite',
#  'frLenlTIMAmici Speciali',
#  'TUTTO LENTOCRZATimgPloy',
#  'l goVresza r',
#  'COSA DEVO FARCIAGPlay',
#  'RESTATE COLLEGATIAlle pubblico un postho bisogno d',
#  'COGEOcrete TOCaINiiiimm cirinFonniVelenieieateaPaA',
#  'in',
#  'SIPLAlSIMA',
#  'martinabeltramiofficialtaidirottacon dumbozzillast',
#  '',
#  '',
#  'fasVasi',
#  '',
#  '',
#  '',
#  'EchedjOCiaiytjg',
#  '',
#  'iapriamaTTnegieidaleLIALIOAiPrtasnU SX di',
#  'I QUARRI DI CiULIANOrewiIL QUADROSTORIA DAMORE',
#  '',
#  'Virna toppiJavier RojasProve per festival diNerviL',
#  '',
#  'EAS ONKOCCAObssesion',
#  'san',
#  'VVAINTERZAPUNIATAO',
#  '',
#  '',
#  'ttUL',
#  'xlTi',
#  'HO PRESO UN PALO',
#  '',
#  'GiovandiregiovanivimartinabeltramimusiciIN DIRETTA',
#  '',
#  '',
#  'CheDioCiAiutiSHCDCASPotrei comprare una nueva Chan',
#  'TALIroyseLane',
#  '',
#  '',
#  '',
#  'Che Dioxci aiutil',
#  'yiMiavicd',
#  'randnm solotlaA tout le mondeOaz in messaggio',
#  '',
#  'llavinitionnAIUISIASETAALIE ALe',
#  'mariti cabeltarmiotiiHicialx',
#  'tsalltenepiaot',
#  'eTULLIO SOI ENGHICTCF',
#  'enI',
#  '',
#  '',
#  'NENOMi piace messi damartipassaggi su Radio Zeta i',
#  'pe eVCITIUOiI CASTINGSONOAPERTIf IT LlGSOAVNo REFT',
#  'ijaviufficiale  renaramo ma che cazzoPIER SThPiace',
#  'CINA',
#  'fvo',
#  'N',
#  'Jacopo Blue MondayNessuna visualizzazione  O secon',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'scanthony donadio',
#  'CONVENT MYSTERIESSOSEZOlaSERITTQuo aiIE',
#  '',
#  'SOCIALBLOGIv',
#  '',
#  'Qusit',
#  '',
#  '',
#  'earsidee',
#  'Ds',
#  '',
#  'CONVENT MYSTERIESSOElavJDIO',
#  'SXndisNongTa',
#  '',
#  'stefanotarinettiSend messageO',
#  '',
#  'tag n',
#  'n',
#  '',
#  'deleuni',
#  'USesbaLenega seearomnWarblsiciruioa',
#  '',
#  'NEG ZoneCHE SUCCEDE',
#  'CONVENT MYSTERIESSOElavSegaTToudic',
#  'Vai f',
#  'fi',
#  'ra',
#  'TG',
#  'Vfo',
#  'RAI fRAIRAIRETECANALE SITALIATvaELLIZLrCIrECSRCIR ',
#  'se SS',
#  '',
#  'A',
#  'Trasmesso in tre parti il e agostodalle ZCO alle s',
#  '',
#  'Questa canzone il miocontributo per portare un pez',
#  'CONVENT MYSTERIESSOElavJe',
#  'MAI UNA GIOIA',
#  'claroratfedericacristianoIUDICI LOVO',
#  'giulycookieVeneidi ZME A ZIAMaggio alle oreOArmiaz',
#  'CHIEDO',
#  'JAVIEROGGI ore l',
#  'AC coDi tilnOMICAS',
#  '',
#  '',
#  'CONVENT MYSTERIESSOElavSegaTTousare odo',
#  '',
#  'ielspo nnettdatosiasiafioNVvQ',
#  'FilDIdgPIO STA a RIP NEUAGioved Maggioi TiaWwwwlad',
#  '',
#  'CONVENT MYSTERIESSOEGlavJsianz',
#  'MiPiay',
#  '',
#  'novoiany',
#  '',
#  'javiufficialeProinofestival nerviImma DiObatuzer a',
#  'MAI UNA GIOIA',
#  'Mi dispiace che avevodetto altro ho sbagliatoOR CE',
#  'A UURTTNR',
#  'x',
#  '',
#  'LAVA',
#  'fpaolabale qiordanaangiOInvia un MessaggioIllLD',
#  'foneg PIXARoeydIiNIJ',
#  'CHE DIO CI SALVI',
#  'Quando Quando Quandofeat JAX',
#  'SUsa RNdet LITaNestrtonii TuabititriuqbiNifeho GCA',
#  '',
#  'TitDLapteLiTT A',
#  'wAHNO',
#  '',
#  'Per aiutare Javi nelrecupero del suoaccountSIE SEG',
#  '',
#  's',
#  '',
#  'giulycookieLascia una sola domandaper RandomATxOIn',
#  'apaEF',
#  '',
#  '',
#  'o TikTOK',
#  '',
#  '',
#  '',
#  '',
#  'eeI',
#  '',
#  '',
#  'TOseeIAy',
#  'asdnre laSdleserVA',
#  'DIO DELLE CITTARARA',
#  '',
#  'J',
#  '',
#  '',
#  'L',
#  '',
#  '',
#  '',
#  '',
#  'pi fortedlMie TrrrVveYa AAdr',
#  'lgiulycookieMi Neno faccio tardi pure oggiXORTIETr',
#  'ua',
#  '',
#  '',
#  'RESTATE COLLEGATIAlle pubblico un postho bisogno d',
#  'CONVENT MYSTERIESSOETlavSegaTTouA',
#  '',
#  'llCIRETTABALLANDO LA RIVINCITA Di COSTANTIRti',
#  '',
#  '',
#  'CONVENT MYSTERIESSOElavJsianz',
#  'dodn',
#  'DIO DELLE CITTARARA',
#  '',
#  'SOCIALBLOGIv',
#  '',
#  '',
#  'prpII',
#  '',
#  'giulycookiebtNRE MRluiiiiSola se non hai gi fattoP',
#  '',
#  'verbelaATTENZIONIitiLiEA adnnralarlaervlVialIl',
#  '',
#  '',
#  'GESIIVUEEFmio MERAVIGLIA diapreciataretemi gttupai',
#  'i vdj',
#  'Tvzf',
#  'DI nei LIVE',
#  '',
#  'ho e Te',
#  'escrusi ouriAMICI SPECIALInYwl',
#  'TROSHITAFIAHI',
#  'SOCIALBLOGIv',
#  'SOCIALBLOGIv',
#  'A MlAaAleDIritaVI AeatoaiToanJAat Ainragianceglivi',
#  'em',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Il MOMENTODEL CAMBIAMENTOSPEZZONE DI FILM',
#  'A',
#  '',
#  '',
#  '',
#  'miti',
#  '',
#  '',
#  'iLi',
#  '',
#  'WWWRADIOBASEFM',
#  'TRASH ITALIANO',
#  '',
#  'lunamiant ivoulPACCiac',
#  'SvegliaSveglia ogni giornoOSveglia ogni giornoSveg',
#  'X ALBERTO URSO PresalvumusicdigitalSaGrazie per av',
#  '',
#  '',
#  '',
#  'siITETANHUTaAt HETmlNenoryrmipleCeRealaUmerutianel',
#  ' FILMHOUSE',
#  'de',
#  'TRASH ITALIANOAMORE',
#  'aDOPOAdFIMidoAStri rEAveulsuorgiiafadi LU Tf',
#  'ae paoeRgIs INTV STASERAGIOVEDI II GIUGNOwwwSPETTA',
#  'AOeinZire va eliCY',
#  'JPI',
#  'xSTPODCASTTIMIntervista a JavierOIntervista a Javi',
#  'jS',
#  'f',
#  '',
#  'oabpif',
#  'Aiale',
#  '',
#  '',
#  'VIPERISSISIACI VUOLE LA COMPLETEZZA',
#  'usibeltramiLELO',
#  'CONVENT MYSTERIESSOEglavTHTa',
#  'EAEAe ltTATA LITTAraminQFONAIEANrrMTUTDADI',
#  'Sane O anni che stiamoaspertardo questo momento',
#  '',
#  'caiarsiacidossoVabbe ivi voliarnio tutti i',
#  '',
#  'NICOLAIospite asabato maggio ore O',
#  '',
#  'ent',
#  '',
#  'rrgiulycookie iil Martina Beltrami Luci AcceseXxXO',
#  'IN DIRETTA CONVea ca RoVIZZINIMERCOLED MAGGIOditl ',
#  'nl stellaAR',
#  'manite raminIisicicinane',
#  '',
#  'aNAvouf',
#  'Mi viene da piangere',
#  'Roil PlayRiguardareferitedelle tuesOtoACasHI Res',
#  '',
#  'epen',
#  '',
#  '',
#  '',
#  'azzurralandVyAradIpo',
#  'Quando parte la fotoconla telecamerainterna ma tu ',
#  '',
#  '',
#  'Gaia  Chega Lyric VideoGaia',
#  'dA',
#  'lIgglMusicaGood TimesEls Ran PINTANiCamice biancoG',
#  'dlLEOAeAPiace BD e altre personegiutymol Il tramon',
#  '',
#  'rTGRAZIE cOL CUORE',
#  '',
#  'g SpotifyNfaccio tardi pure oggii I bi',
#  '',
#  '',
#  'IAdi',
#  '',
#  '',
#  'POSSO ACCETTARE TUTTOMA LA TIRCHIEZZAQUELLA NODio',
#  '',
#  '',
#  '',
#  '',
#  'I',
#  'silnapaco',
#  '',
#  '',
#  'diSu',
#  'a',
#  '',
#  '',
#  'faDainun U',
#  'nisiavx',
#  'LL',
#  'WHOtiTPdb',
#  '',
#  'dTRA POCO IL VINCITOREDI AMICI OPREMIOTIMdella cri',
#  'vi',
#  '',
#  'J',
#  'cailditiviviDididnnvi',
#  'se dmv',
#  'advai',
#  'TsxSAESSVIAdotin IsdidStInoveAA at',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'thNeRZaVihgivi',
#  'Tendenze ItaliaVAI a CI Ve CacciariCA crA odheauti',
#  'CaAH OKAY',
#  '',
#  'ottonellojgemmyiooAuguri amoremiosono i sei mesipi',
#  '',
#  '',
#  'UL RT IRESTARTETC EIIENttTIRTITIICIRIEEOTTTICostan',
#  '',
#  '',
#  '',
#  'esb',
#  'HounamiciziabellissimaconJacopo con lui ho avuto s',
#  '',
#  'ESCLUSIoItlSddvildo',
#  '',
#  'br',
#  'LeEnrico e Lisa alchimianiaArieoimgPlay',
#  '',
#  'a',
#  'id',
#  'AL',
#  'vo',
#  'AVVIA VV VVVV VV VV',
#  '',
#  'javiufficiale  gaiaofficial lovelhPiace a Z person',
#  'SONO TROPPO FELICE',
#  'dhpiSE',
#  '',
#  '',
#  '',
#  'siuu BEX TOSho',
#  'a nNi ci',
#  'talisajadelson stato aletto per due giorni dopo qu',
#  '',
#  '',
#  'Pr Pdianadelbufalogiasaunale',
#  'Pei LI',
#  '',
#  '',
#  '',
#  'Cainiiaceteiepr neaPREsuiA M',
#  '',
#  '',
#  '',
#  'EiHDEnSOIdrdNasi',
#  'PoIll MalVIieCoSVV DIBraniVedi tuttoTo Camice bian',
#  'lTTgiulymolI GhaliOta IL LFIsaggio',
#  '',
#  '',
#  'Jacopo Blue MondayNessuna visualizzazione secondi ',
#  'pastieTod',
#  '',
#  'ottonellojJHUUILIUE MOnDAvFLIORI DOMANI ALLEMP LIG',
#  '',
#  '',
#  'Come promessoavrei condiviso con voi una cosaper m',
#  'giulymol',
#  'LANLILLmieiecaidi',
#  'EMOGIATIimQPlay',
#  'VIPERISSIMA',
#  'galagozzifan SnEee re ESTEia e AaaiatdREtdSeAvaaRA',
#  'i nyvofficialDalla mediait creaFammi una domandaIT',
#  '',
#  'nenotficial ealoriaCgVO',
#  '',
#  'n',
#  'UL RTRESTARTETC EIIENttTIRIOTRELOrtESTILICISETTICR',
#  'Branla LangRIPRODIer ARAiiieee TIIInare',
#  '',
#  '',
#  'aallellserdIileA',
#  '',
#  '',
#  'Parolacce',
#  '',
#  '',
#  'stefanofarinettidlOInvia un messaggio',
#  '',
#  'I',
#  'villies',
#  '',
#  '',
#  'imanyeasy ha commentato I hopeI brought you luck T',
#  'E',
#  'IL MONDO DELLA DANZA SAGMOCALATimgPlay',
#  '',
#  '',
#  '',
#  'ninolIUU',
#  'ITikTOk',
#  'uias',
#  '',
#  '',
#  '',
#  'Z',
#  'Av',
#  'UL RT IERRI TIITOISE CIMICNtATARTRUtICItCcostantin',
#  'LfnA ggxee en an',
#  ...]
