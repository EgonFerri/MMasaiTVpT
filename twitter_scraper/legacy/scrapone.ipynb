# %%
import tweepy
import pandas as pd
import requests
from PIL import Image
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import os

# %%
consumer_key = "ze86jWS8Mlac9oSH4LdVRHCvV"
consumer_secret = "QGnX0ATddMPDT9oaRh3RH9s2uXenD4KFpiosMEjC1F5rUMrCH0"
access_token = "366327791-wJ6fT2IKcG1xbK5OWoTLezJJbltVB2LbKLSAQIgw"
access_token_secret = "cza8zVMAZ62cf97cDLhJOGilMS07d1GAEVp067HbiM59r"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
username = "AlterEgon10"
count = 5
try:
    # Creation of query method using parameters
    tweets = tweepy.Cursor(api.user_timeline, id=username).items(count)

    # Pulling information from tweets iterable object
    tweets_list = [[tweet.created_at, tweet.id, tweet.text, tweet.entities] for tweet in tweets]

    # Creation of dataframe from tweets list
    # Add or remove columns as you remove tweet information
    tweets_df = pd.DataFrame(tweets_list)
except BaseException as e:
    print("failed on_status,", str(e))
    time.sleep(3)

# %%
url = tweets_df[3][0]["media"][0]["media_url"]
response = requests.get(url)
file = open("sample_image.png", "wb")
file.write(response.content)
file.close()
im = Image.open("sample_image.png")
plt.imshow(im)

# %%
count = 200
try:
    # Creation of query method using parameters
    tweets = tweepy.Cursor(api.search, q="LAllieva3").items(count)

    # Pulling information from tweets iterable object
    tweets_list = [[tweet.id, tweet.created_at,  tweet.text, tweet.entities['media'][0]['media_url']] for tweet in tweets
                   if ('media' in tweet.entities and 'RT' not in tweet.text)]

    # Creation of dataframe from tweets list
    # Add or remove columns as you remove tweet information
    tweets_df = pd.DataFrame(tweets_list, columns =['id', 'date',  'text', 'url'])
    #tweets_df.set_index('id', inplace=True)
except BaseException as e:
    print("failed on_status,", str(e))
    time.sleep(3)

# %%
tweets_df
# Out:
#                      id                date  \
# 0   1320761809931034624 2020-10-26 16:18:48
# 1   1320761653793873922 2020-10-26 16:18:11
# 2   1320761244639440906 2020-10-26 16:16:33
# 3   1320761032424493057 2020-10-26 16:15:43
# 4   1320760642056409090 2020-10-26 16:14:10
# 5   1320759837240758274 2020-10-26 16:10:58
# 6   1320756888804466688 2020-10-26 15:59:15
# 7   1320755979089285120 2020-10-26 15:55:38
# 8   1320755796871909377 2020-10-26 15:54:55
# 9   1320754791354687488 2020-10-26 15:50:55
# 10  1320752569145327618 2020-10-26 15:42:05
# 11  1320747248259633152 2020-10-26 15:20:56
# 12  1320743078358036481 2020-10-26 15:04:22
# 13  1320740727916212232 2020-10-26 14:55:02
# 14  1320740154550579201 2020-10-26 14:52:45
# 15  1320738493572796419 2020-10-26 14:46:09
# 16  1320734653393895425 2020-10-26 14:30:54
#
#                                                  text  \
# 0            17 👀\n#lallieva3 https://t.co/sSPyhjZltw
# 1   Scusate ma dovevo farlo hahahaj✈️✈️ #lallieva3...
# 2   Io tutta la serata di ieri\n#lallieva3 https:/...
# 3   Quando sei già incazzata di tuo e qualcuno ti ...
# 4   Quando qualcuno che non sopporto mi interrompe...
# 5   Non riesco a smettere di ridere aiuto \n#lalli...
# 6   Imperioso 🔥🔥🔥\n\n#lallieva3 #biscottohot #cc h...
# 7   La mano dietro la testa, fin dall’inizio...🥺💙\...
# 8   Visto che il video tra Alice e la Manes è anco...
# 9   Se qui non avete pianto, state mentendo\n#lall...
# 10  Finalmente una notizia sensata! #lallieva3 htt...
# 11  #lallieva3\n Mmmmm… 🍓 yeah, fuck my face. 🔥 ht...
# 12   mamma Lara❤️\n#lallieva3 https://t.co/rjHyxk5gOK
# 13  È insuperabile in queste scene. Le sue emozion...
# 14  E allora raga su richiesta vi spammo pure ques...
# 15  “e poi ho incontrato te, e ti amo”\nGiacomo e ...
# 16  Un limone di cui difficilmente ci dimentichere...
#
#                                                   url
# 0      http://pbs.twimg.com/media/ElRJ3VFX0AIJfg6.jpg
# 1      http://pbs.twimg.com/media/ElRJt_0XEAAQ7Pm.jpg
# 2      http://pbs.twimg.com/media/ElRJWcLWMAA_fRb.jpg
# 3   http://pbs.twimg.com/tweet_video_thumb/ElRJJs7...
# 4   http://pbs.twimg.com/tweet_video_thumb/ElRIy6i...
# 5   http://pbs.twimg.com/tweet_video_thumb/ElRIESj...
# 6   http://pbs.twimg.com/tweet_video_thumb/ElRFXKu...
# 7      http://pbs.twimg.com/media/ElREj5tXUAAkBbC.jpg
# 8   http://pbs.twimg.com/ext_tw_video_thumb/132075...
# 9      http://pbs.twimg.com/media/ElRDeuFXIAEqFDM.jpg
# 10     http://pbs.twimg.com/media/ElRBdhNXUAUunGB.jpg
# 11     http://pbs.twimg.com/media/ElQ8nZtXIAMi9Gj.jpg
# 12     http://pbs.twimg.com/media/ElQ40yRX0AEVDPj.jpg
# 13     http://pbs.twimg.com/media/ElQ2sHeWoAE2Hn9.jpg
# 14  http://pbs.twimg.com/ext_tw_video_thumb/132074...
# 15  http://pbs.twimg.com/ext_tw_video_thumb/132073...
# 16     http://pbs.twimg.com/media/ElQxKgbX0AA4KU8.jpg

# %%
url = tweets_df['url'][0]
response = requests.get(url)
file = open("sample_image.png", "wb")
file.write(response.content)
file.close()
im = Image.open("sample_image.png")
plt.imshow(im)

# %%
'media' in tweets_df[3][0]
# Out:
# True

# %%
'media' in tweets_list[0][3]
# Out:
# False

# %%
    tweets = tweepy.Cursor(api.search, q="LAllieva3").items(count)

    # Pulling information from tweets iterable object
    tweets_list = [[tweet.id, tweet.created_at,  tweet.text, tweet.entities['media'][0]['media_url']] for tweet in tweets
                   if ('media' in tweet.entities and 'RT' not in tweet.text)]

# %%
yesterday = date.today() - timedelta(days=1)
yesterday.strftime('%Y-%m-%d')
# Out:
# '2020-10-25'

# %%
def df_maker(hashtag, count=100):
    try:
        # Creation of query method using parameters
        tweets = tweepy.Cursor(api.search, q=hashtag).items(count)

        # Pulling information from tweets iterable object
        tweets_list = [[tweet.id, tweet.created_at,  tweet.text, tweet.entities['media'][0]['media_url']] for tweet in tweets
                       if ('media' in tweet.entities and 'RT' not in tweet.text[:2])]

        # Creation of dataframe from tweets list
        # Add or remove columns as you remove tweet information
        tweets_df = pd.DataFrame(tweets_list, columns =['id', 'date',  'text', 'url'])
    except BaseException as e:
        print("failed on_status,", str(e))
        time.sleep(3)
    return(tweets_df)

# %%
def save_url(index, url, path):
    try:
        os.makedirs(path)
    except:
        pass
    response = requests.get(url)
    file = open(f"{path}/{index}.png", "wb")
    file.write(response.content)
    file.close()

# %%
def image_saver(df, path):
    for idx, row in df.iterrows():
        index=row['id']
        url=row['url']
        save_url(index, url, path)

# %%
def scraper(hashtag, count):
    try:
        os.makedirs(f"data/{hashtag}")
    except:
        pass
    dataframe=df_maker(hashtag, count)
    image_saver(dataframe, f"data/{hashtag}/images")
    try:
        old=pd.read_csv(f"data/{hashtag}/data.csv")
        dataframe=old.append(dataframe)
        dataframe=dataframe.drop_duplicates(subset='id')
    except:
        pass
    dataframe.to_csv(path_or_buf=f"data/{hashtag}/data.csv", index=False)
    return 'tutto ok'

# %%
pd.read_csv(f"data/Donmatteo/data.csv")
# Out:
#                     id                 date  \
# 0  1320419132047872001  2020-10-25 17:37:07
# 1  1320418104393031681  2020-10-25 17:33:02
# 2  1319381895768084480  2020-10-22 20:55:31
# 3  1319381286461575181  2020-10-22 20:53:06
# 4  1319308968410468352  2020-10-22 16:05:44
# 5  1319174880374509568  2020-10-22 07:12:55
# 6  1318988365946040326  2020-10-21 18:51:46
#
#                                                 text  \
# 0  Questa è la chiesa dove viene girata le serie....
# 1  Oggi sono stata a Spoleto, dove si gira #donma...
# 2  Ma è l’appuntato Barba di #DonMatteo\n\n#DocNe...
# 3  Barba\n#DocNelleTueMani #DonMatteo https://t.c...
# 4  #DonMatteo arriva in libreria con le «indagini...
# 5  Ma che davero?! #donmatteo #donbabbeo #unapeco...
# 6  Hold the line\nLove isn't always on time\n\n#D...
#
#                                               url
# 0  http://pbs.twimg.com/media/ElMSIwrWMAEjOnE.jpg
# 1  http://pbs.twimg.com/media/ElMRMN9WMAI30Y-.jpg
# 2  http://pbs.twimg.com/media/Ek9i1quXUAANgtA.jpg
# 3  http://pbs.twimg.com/media/Ek9iSYjXIAAzCf_.jpg
# 4  http://pbs.twimg.com/media/Ek8gQzYWkAQaDyK.jpg
# 5  http://pbs.twimg.com/media/Ek6mjYFXUAAjChl.jpg
# 6  http://pbs.twimg.com/media/Ek387DeXYAAoNsd.jpg

# %%
scraper('lallieva3', 100)
# Out:
# 'tutto ok'

# %%
res.append(res).drop_duplicates()
# Out:
#                     id                date  \
# 0  1320419132047872001 2020-10-25 17:37:07
# 1  1320418104393031681 2020-10-25 17:33:02
# 2  1319381895768084480 2020-10-22 20:55:31
# 3  1319381286461575181 2020-10-22 20:53:06
# 4  1319308968410468352 2020-10-22 16:05:44
# 5  1319174880374509568 2020-10-22 07:12:55
# 6  1318988365946040326 2020-10-21 18:51:46
# 7  1318517837401653250 2020-10-20 11:42:03
#
#                                                 text  \
# 0  Questa è la chiesa dove viene girata le serie....
# 1  Oggi sono stata a Spoleto, dove si gira #donma...
# 2  Ma è l’appuntato Barba di #DonMatteo\n\n#DocNe...
# 3  Barba\n#DocNelleTueMani #DonMatteo https://t.c...
# 4  #DonMatteo arriva in libreria con le «indagini...
# 5  Ma che davero?! #donmatteo #donbabbeo #unapeco...
# 6  Hold the line\nLove isn't always on time\n\n#D...
# 7  Primi sorrisi ❤\n\n#DonMatteo #DonMatteo11 #Do...
#
#                                               url
# 0  http://pbs.twimg.com/media/ElMSIwrWMAEjOnE.jpg
# 1  http://pbs.twimg.com/media/ElMRMN9WMAI30Y-.jpg
# 2  http://pbs.twimg.com/media/Ek9i1quXUAANgtA.jpg
# 3  http://pbs.twimg.com/media/Ek9iSYjXIAAzCf_.jpg
# 4  http://pbs.twimg.com/media/Ek8gQzYWkAQaDyK.jpg
# 5  http://pbs.twimg.com/media/Ek6mjYFXUAAjChl.jpg
# 6  http://pbs.twimg.com/media/Ek387DeXYAAoNsd.jpg
# 7  http://pbs.twimg.com/media/EkxQ87kW0AEFHDz.jpg
